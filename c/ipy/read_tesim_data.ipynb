# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
fname = r'd:/git/tesim/c/teplant.dat'
d = np.loadtxt(fname, delimiter="\t")

t=np.array(d[:,0])
xmeas_offset = 12
reac_inds = range(16,21)
print(reac_inds)

for ii in range(4):
    ind = reac_inds[ii] 
    print(ind)
    plt.subplot(2,2,ii)
    plt.plot(t,d[:,ind])
    plt.grid(True)
# Out:
# range(16, 21)
# 16
# 17
# 18
# 19
