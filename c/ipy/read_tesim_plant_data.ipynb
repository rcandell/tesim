# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
fname = r'd:/git/tesim/c/teplant.dat'
d = np.loadtxt(fname, delimiter="\t")

# %%
xmv_names = [
'D Feed',
'E Feed',
'A Feed',
'A+C Feed',
'Recycle Valve',
'Purge Valve',
'Separator Valve',
'Stripper Valve',
'Steam valve',
'Reactor Coolant',
'Condenser Coolant',
'Agitator Speed' ]

xmeas_names = [
'A Feed',
'D Feed',
'E Feed',
'A+C Feed',
'Recycle Flow',
'Reactor Feed',
'Reactor Pressure',
'Reactor Level',
'Reactor Temp.',
'Purge Rate',
'Sep Temp',
'Sep Level',
'Sep Pressure',
'Sep Underflow',
'Stripper Level',
'Stripper Pressure',
'Stripper Underflow',
'Stripper Temp.',
'Steam Flow',
'Compressor Work',
'React. Cool. Temp.',
'Cond. Cool. Temp.',
'Feed A',
'Feed B',
'Feed C',
'Feed D',
'Feed E',
'Feed F',
'Purge     % A',
'Purge     % B',
'Purge     % C',
'Purge     % D',
'Purge     % E',
'Purge     % F',
'Purge     % G',
'Purge     % H',
'Product D',
'Product E',
'Product F',
'Product G',
'Product H' ]

# %%
plt.figure(figsize=(16,52))
t=np.array(d[:,0])
for ii in range(0,41):
    ind = ii+12
    plt.subplot(11,4,ii+1)
    plt.plot(t,d[:,ind])
    plt.title(xmeas_names[ii])

# %%
# plot all of the measured variables as seen by the plant
plt.figure(figsize=(10,12))
t=np.array(d[:,0])
for ii in range(0,12):
    ind = ii+12
    plt.subplot(4,3,ii+1)
    plt.plot(t,d[:,ind])
    plt.title(xmeas_names[ii])
